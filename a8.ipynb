# %% [markdown]
# # Equipe
#
# Tiago Vargas Pereira de Oliveira
#
# Lucas Alves de Oliveira

# %%
from fun import compute_adjacency_list_from

# %% [markdown]
# # Q1
#
# **Implemente o algoritmo usando lista de adjacência para modelar o grafo abaixo:**
#
# ![image.png](attachment:image.png)

# %%
node_names = ['1', '2', '3', '4', '5', '6', '7', '8', '9']

graph = [
	# 1, 2, 3, 4, 5, 6, 7, 8, 9
	[ 0, 1, 0, 1, 1, 0, 0, 0, 0],  # 1
	[ 1, 0, 1, 0, 1, 0, 0, 0, 0],  # 2
	[ 0, 1, 0, 0, 0, 0, 0, 0, 1],  # 3
	[ 1, 0, 0, 0, 1, 0, 0, 0, 0],  # 4
	[ 1, 1, 0, 1, 0, 0, 0, 0, 0],  # 5
	[ 0, 0, 0, 0, 0, 0, 1, 1, 0],  # 6
	[ 0, 0, 0, 0, 0, 1, 0, 1, 0],  # 7
	[ 0, 0, 0, 0, 0, 1, 1, 0, 0],  # 8
	[ 0, 0, 1, 0, 0, 0, 0, 0, 0],  # 9
]

# %%
def pretty_print(adjacency_list: list[list[str]], node_names: list[str]):
	for (node_name, neighbors) in zip(node_names, adjacency_list):
		print(f"'{node_name}': {neighbors}")

# %%
l = compute_adjacency_list_from(graph, node_names)
pretty_print(l, node_names)
# Out:
# '1': ['2', '4', '5']
# '2': ['1', '3', '5']
# '3': ['2', '9']
# '4': ['1', '5']
# '5': ['1', '2', '4']
# '6': ['7', '8']
# '7': ['6', '8']
# '8': ['6', '7']
# '9': ['3']
