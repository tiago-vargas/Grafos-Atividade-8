# %% [markdown]
# # Equipe
#
# Tiago Vargas Pereira de Oliveira
#
# Lucas Alves de Oliveira

# %%
from fun import compute_adjacency_list_from, count_connected_components, topological_sort, partial_topological_sort
# from fun import count_connected_components

# %% [markdown]
# # Q1
#
# **Implemente o algoritmo usando lista de adjacência para modelar o grafo abaixo:**
#
# ![image.png](attachment:image.png)

# %%
node_names = ['1', '2', '3', '4', '5', '6', '7', '8', '9']

graph = [
	# 1, 2, 3, 4, 5, 6, 7, 8, 9
	[ 0, 1, 0, 1, 1, 0, 0, 0, 0],  # 1
	[ 1, 0, 1, 0, 1, 0, 0, 0, 0],  # 2
	[ 0, 1, 0, 0, 0, 0, 0, 0, 1],  # 3
	[ 1, 0, 0, 0, 1, 0, 0, 0, 0],  # 4
	[ 1, 1, 0, 1, 0, 0, 0, 0, 0],  # 5
	[ 0, 0, 0, 0, 0, 0, 1, 1, 0],  # 6
	[ 0, 0, 0, 0, 0, 1, 0, 1, 0],  # 7
	[ 0, 0, 0, 0, 0, 1, 1, 0, 0],  # 8
	[ 0, 0, 1, 0, 0, 0, 0, 0, 0],  # 9
]

# %%
compute_adjacency_list_from(graph, node_names)
# Out:
# {'1': ['2', '4', '5'],
#  '2': ['1', '3', '5'],
#  '3': ['2', '9'],
#  '4': ['1', '5'],
#  '5': ['1', '2', '4'],
#  '6': ['7', '8'],
#  '7': ['6', '8'],
#  '8': ['6', '7'],
#  '9': ['3']}

# %% [markdown]
# # Q2
#
# **Faça um algoritmo para o grafo da questão 1, em que conta quantos componentes conexos existem**
#
# **PS: Pode usar qualquer estrutura de grafos.**

# %%
count_connected_components(compute_adjacency_list_from(graph, node_names))
# Out:
# 2

# %% [markdown]
# # Q3
#
# **Implemente uma lista de adjacência do grafo direcionado abaixo, ainda conte quantos graus tem em cada nó (saída e entrada):**
#
# ![image.png](attachment:image.png)

# %%
node_names = ['a', 'c', 'v', 'd', 'w', 'f']
graph = [
	#  a,  c,  v,  d,  w,  f
	[  0,  1,  1,  0,  0,  0],  # a
	[ -1,  0,  0,  0,  1,  0],  # c
	[ -1,  0,  0,  1,  1,  0],  # v
	[  0,  0, -1,  0,  0,  1],  # d
	[  0, -1, -1,  0,  0,  1],  # w
	[  0,  0,  0, -1, -1,  0],  # f
]

# %%
compute_adjacency_list_from(graph, node_names)
# Out:
# {'a': ['c', 'v'], 'c': ['w'], 'v': ['d', 'w'], 'd': ['f'], 'w': ['f'], 'f': []}

# %% [markdown]
# # Q4
#
# **Implemente o algoritmo, em que a entrada é uma matriz de incidência com 4 nós 6 arestas de um grafo não dirigido, o programa vai mostrar a quantidade componentes conexos do grafo?**

# %% [markdown]
# # Q5
#
# **Implemente com a linguagem de sua preferência 2 ordenações topológica do "grafo e a estrutura (lista de adjacência) da questão 3"**

# %%
topological_sort(compute_adjacency_list_from(graph, node_names))
# Out:
# ['a', 'v', 'd', 'c', 'w', 'f']

# %%
partial_topological_sort(compute_adjacency_list_from(graph, node_names))
# Out:
# ['a', 'c', 'v', 'd', 'w', 'f']
